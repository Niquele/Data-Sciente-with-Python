# %% [markdown]
# Multi Index

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.set_index(['Sex','Age'],inplace=True)

# %%
df
# Out:
#              PassengerId  Survived  Pclass  \
# Sex    Age
# male   22.0            1         0       3
# female 38.0            2         1       1
#        26.0            3         1       3
#        35.0            4         1       1
# male   35.0            5         0       3
# ...                  ...       ...     ...
#        27.0          887         0       2
# female 19.0          888         1       1
#        NaN           889         0       3
# male   26.0          890         1       1
#        32.0          891         0       3
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# male   22.0                            Braund, Mr. Owen Harris      1      0
# female 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
#        26.0                             Heikkinen, Miss. Laina      0      0
#        35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# ...

# %%
df.index
# Out:
# MultiIndex([(  'male', 22.0),
#             ('female', 38.0),
#             ('female', 26.0),
#             ('female', 35.0),
#             (  'male', 35.0),
#             (  'male',  nan),
#             (  'male', 54.0),
#             (  'male',  2.0),
#             ('female', 27.0),
#             ('female', 14.0),
#             ...
#             (  'male', 33.0),
#             ('female', 22.0),
#             (  'male', 28.0),
#             (  'male', 25.0),
#             ('female', 39.0),
#             (  'male', 27.0),
#             ('female', 19.0),
#             ('female',  nan),
#             (  'male', 26.0),
#             (  'male', 32.0)],
#            names=['Sex', 'Age'], length=891)

# %%
df.loc['female',22] #tras o dataframe somente onde o valor é true
# Out:
# C:\Users\nique\AppData\Local\Temp\ipykernel_18632\3977691338.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc['female',22] #tras o dataframe somente onde o valor é true
#              PassengerId  Survived  Pclass  \
# Sex    Age
# female 22.0          142         1       3
#        22.0          152         1       1
#        22.0          290         1       3
#        22.0          324         1       2
#        22.0          357         1       1
#        22.0          377         1       3
#        22.0          475         0       3
#        22.0          540         1       1
#        22.0          555         1       3
#        22.0          609         1       2
#        22.0          709         1       1
#        22.0          883         0       3
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# female 22.0                           Nysten, Miss. Anna Sofia      0      0
# ...
